# %%
from PIL import Image

image = Image.open('../data/valid/4375/5.png')
image.show()
image = Image.open('../data/valid/4375/14.png')
image.show()
image = Image.open('../../../data/4375/5.png')
image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
